# %%
from requests import Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  # print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# type(data)

import pandas as pd

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11025
# 1    1027      Ethereum    ETH      ethereum              8903
# 2     825   Tether USDt   USDT        tether             84934
# 3    1839           BNB    BNB           bnb              2154
# 4    5426        Solana    SOL        solana               656
# 5    3408          USDC   USDC      usd-coin             18946
# 6      52           XRP    XRP           xrp              1314
# 7      74      Dogecoin   DOGE      dogecoin               962
# 8   11419       Toncoin    TON       toncoin               312
# 9    2010       Cardano    ADA       cardano              1162
# 10   5994     Shiba Inu   SHIB     shiba-inu               806
# 11   5805     Avalanche   AVAX     avalanche               719
# 12   1958          TRON    TRX          tron               972
# 13   6636      Polkadot    DOT  polkadot-new               755
# ...

# %%
# Working on Crypto Currency/ APIs - Involves Automation & Data Cleaning

# %%
# Adding a time stamp to find out when I did the operations/ adding it at the end of the columns

# %%
def api_runner():
    # global df

    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')

    if not os.path.isfile(r"/Users/niladreeb/Documents/MyPythonTutorial/API.csv"):
        df.to_csv(r"/Users/niladreeb/Documents/MyPythonTutorial/API.csv", header = 'column_names')
    else:
        df.to_csv(r"/Users/niladreeb/Documents/MyPythonTutorial/API.csv", mode = 'a', header = False)

# %%
import os
from time import time
from time import sleep

for i in range(10):
    api_runner()
    print('API runner completed successfully')
    sleep(5)
exit()
# Out:
# API runner completed successfully
# API runner completed successfully
# API runner completed successfully
# API runner completed successfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 8
#       6     api_runner()
#       7     print('API runner completed successfully')
# ----> 8     sleep(5)
#       9 exit()
#
# KeyboardInterrupt:

# %%
df444=pd.read_csv (r"/Users/niladreeb/Documents/MyPythonTutorial/API.csv")
df444
# Out:
#      Unnamed: 0     id          name symbol          slug  num_market_pairs  \
# 0             0      1       Bitcoin    BTC       bitcoin             11025
# 1             1   1027      Ethereum    ETH      ethereum              8902
# 2             2    825   Tether USDt   USDT        tether             84919
# 3             3   1839           BNB    BNB           bnb              2154
# 4             4   5426        Solana    SOL        solana               656
# 5             5   3408          USDC   USDC      usd-coin             18943
# 6             6     52           XRP    XRP           xrp              1314
# 7             7     74      Dogecoin   DOGE      dogecoin               962
# 8             8  11419       Toncoin    TON       toncoin               312
# 9             9   2010       Cardano    ADA       cardano              1162
# 10           10   5994     Shiba Inu   SHIB     shiba-inu               805
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11025
# 1    1027      Ethereum    ETH      ethereum              8903
# 2     825   Tether USDt   USDT        tether             84934
# 3    1839           BNB    BNB           bnb              2154
# 4    5426        Solana    SOL        solana               656
# 5    3408          USDC   USDC      usd-coin             18946
# 6      52           XRP    XRP           xrp              1314
# 7      74      Dogecoin   DOGE      dogecoin               962
# 8   11419       Toncoin    TON       toncoin               312
# 9    2010       Cardano    ADA       cardano              1162
# 10   5994     Shiba Inu   SHIB     shiba-inu               806
# 11   5805     Avalanche   AVAX     avalanche               719
# 12   1958          TRON    TRX          tron               972
# 13   6636      Polkadot    DOT  polkadot-new               755
# ...

# %%
# The above command will convert the digital value to float

# %%
df3 = df.groupby('name', sort = False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#               quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          -0.13133                      -2.35357
# Ethereum                          0.62592                      -2.40350
# Tether USDt                      -0.00241                      -0.03266
# BNB                               0.98454                       0.93167
# Solana                            0.40721                      -6.36833
# USDC                              0.00556                      -0.01737
# XRP                              -0.26844                      -2.19312
# Dogecoin                         -0.76577                      -6.02914
# Toncoin                           0.49573                      -0.88710
# Cardano                           0.03862                       2.18778
# Shiba Inu                         0.01299                      -3.43232
# Avalanche                         0.46483                      -5.52621
# ...

# %%
df4 = df3.stack()

df4
# Out:
# name
# Bitcoin       quote.USD.percent_change_1h     -0.13133
#               quote.USD.percent_change_24h    -2.35357
#               quote.USD.percent_change_30d   -14.19013
#               quote.USD.percent_change_60d   -10.20283
#               quote.USD.percent_change_90d    35.53969
# Ethereum      quote.USD.percent_change_1h      0.62592
#               quote.USD.percent_change_24h    -2.40350
#               quote.USD.percent_change_30d   -19.32116
#               quote.USD.percent_change_60d   -24.02070
#               quote.USD.percent_change_90d    22.31554
# Tether USDt   quote.USD.percent_change_1h     -0.00241
#               quote.USD.percent_change_24h    -0.03266
#               quote.USD.percent_change_30d    -0.01428
#               quote.USD.percent_change_60d    -0.23168
#               quote.USD.percent_change_90d    -0.01827
# BNB           quote.USD.percent_change_1h      0.98454
#               quote.USD.percent_change_24h     0.93167
# ...

# %%
type (df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')

df5
# Out:
#                                              values
# name
# Bitcoin      quote.USD.percent_change_1h   -0.13133
#              quote.USD.percent_change_24h  -2.35357
#              quote.USD.percent_change_30d -14.19013
#              quote.USD.percent_change_60d -10.20283
#              quote.USD.percent_change_90d  35.53969
# Ethereum     quote.USD.percent_change_1h    0.62592
#              quote.USD.percent_change_24h  -2.40350
#              quote.USD.percent_change_30d -19.32116
#              quote.USD.percent_change_60d -24.02070
#              quote.USD.percent_change_90d  22.31554
# Tether USDt  quote.USD.percent_change_1h   -0.00241
#              quote.USD.percent_change_24h  -0.03266
#              quote.USD.percent_change_30d  -0.01428
#              quote.USD.percent_change_60d  -0.23168
#              quote.USD.percent_change_90d  -0.01827
# BNB          quote.USD.percent_change_1h    0.98454
#              quote.USD.percent_change_24h   0.93167
# ...

# %%
df5.count()
# Out:
# values    75
# dtype: int64

# %%
index = pd.Index(range(75))
df6 = df5.reset_index()
df6
# Out:
#             name                       level_1    values
# 0        Bitcoin   quote.USD.percent_change_1h  -0.13133
# 1        Bitcoin  quote.USD.percent_change_24h  -2.35357
# 2        Bitcoin  quote.USD.percent_change_30d -14.19013
# 3        Bitcoin  quote.USD.percent_change_60d -10.20283
# 4        Bitcoin  quote.USD.percent_change_90d  35.53969
# 5       Ethereum   quote.USD.percent_change_1h   0.62592
# 6       Ethereum  quote.USD.percent_change_24h  -2.40350
# 7       Ethereum  quote.USD.percent_change_30d -19.32116
# 8       Ethereum  quote.USD.percent_change_60d -24.02070
# 9       Ethereum  quote.USD.percent_change_90d  22.31554
# 10   Tether USDt   quote.USD.percent_change_1h  -0.00241
# 11   Tether USDt  quote.USD.percent_change_24h  -0.03266
# 12   Tether USDt  quote.USD.percent_change_30d  -0.01428
# 13   Tether USDt  quote.USD.percent_change_60d  -0.23168
# 14   Tether USDt  quote.USD.percent_change_90d  -0.01827
# ...

# %%
df7 = df6.rename(columns={'level_1' : 'percent_change'})
df7
# Out:
#             name                percent_change    values
# 0        Bitcoin   quote.USD.percent_change_1h  -0.13133
# 1        Bitcoin  quote.USD.percent_change_24h  -2.35357
# 2        Bitcoin  quote.USD.percent_change_30d -14.19013
# 3        Bitcoin  quote.USD.percent_change_60d -10.20283
# 4        Bitcoin  quote.USD.percent_change_90d  35.53969
# 5       Ethereum   quote.USD.percent_change_1h   0.62592
# 6       Ethereum  quote.USD.percent_change_24h  -2.40350
# 7       Ethereum  quote.USD.percent_change_30d -19.32116
# 8       Ethereum  quote.USD.percent_change_60d -24.02070
# 9       Ethereum  quote.USD.percent_change_90d  22.31554
# 10   Tether USDt   quote.USD.percent_change_1h  -0.00241
# 11   Tether USDt  quote.USD.percent_change_24h  -0.03266
# 12   Tether USDt  quote.USD.percent_change_30d  -0.01428
# 13   Tether USDt  quote.USD.percent_change_60d  -0.23168
# 14   Tether USDt  quote.USD.percent_change_90d  -0.01827
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h'],['1h'])
df7
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
df7
# Out:
#             name percent_change    values
# 0        Bitcoin             1h  -0.13133
# 1        Bitcoin            24h  -2.35357
# 2        Bitcoin            30d -14.19013
# 3        Bitcoin            60d -10.20283
# 4        Bitcoin            90d  35.53969
# 5       Ethereum             1h   0.62592
# 6       Ethereum            24h  -2.40350
# 7       Ethereum            30d -19.32116
# 8       Ethereum            60d -24.02070
# 9       Ethereum            90d  22.31554
# 10   Tether USDt             1h  -0.00241
# 11   Tether USDt            24h  -0.03266
# 12   Tether USDt            30d  -0.01428
# 13   Tether USDt            60d  -0.23168
# 14   Tether USDt            90d  -0.01827
# 15           BNB             1h   0.98454
# 16           BNB            24h   0.93167
# 17           BNB            30d  -0.30937
# 18           BNB            60d  20.26022
# 19           BNB            90d  84.40070
# 20        Solana             1h   0.40721
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change',y='values', hue = 'name' , data=df7,kind='point')

# %%
df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin      61525.72621 2024-05-08 23:06:51.756277

# %%
#sns.set_theme(style="darkgrid")

#sns.lineplot(x='timestamp',y='quote.USD.price', data = df10)
